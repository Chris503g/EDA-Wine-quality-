# %% [markdown]
# ### Session15 Homework - Data Exploratory (Advanced Python II)
# #### Name : Christofer Alexander Kumentas
# #### Kelas : Data Engineer Batch 5

# %% [markdown]
# #### Checking Introductory Details About Data

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns 

wine_data = pd.read_csv('winequalityN.csv')
wine_data
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
# Look at the first 5 rows 
wine_data.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
# Look at the last 5 rows 
wine_data.tail()
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 6492  red            6.2             0.600         0.08             2.0
# 6493  red            5.9             0.550         0.10             2.2
# 6494  red            6.3             0.510         0.13             2.3
# 6495  red            5.9             0.645         0.12             2.0
# 6496  red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 6492       0.58     10.5        5
# ...

# %%
wine_data.dtypes
# Out:
# type                     object
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
# check the Information about the data and the datatypes of each respective attribute
wine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
wine_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %%
print("Columns :\n", wine_data.columns)
# Out:
# Columns :
#  Index(['type', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
print("Values :\n", wine_data.values)
# Out:
# Values :
#  [['white' 7.0 0.27 ... 0.45 8.8 6]
#  ['white' 6.3 0.3 ... 0.49 9.5 6]
#  ['white' 8.1 0.28 ... 0.44 10.1 6]
#  ...
#  ['red' 6.3 0.51 ... 0.75 11.0 6]
#  ['red' 5.9 0.645 ... 0.71 10.2 5]
#  ['red' 6.0 0.31 ... 0.66 11.0 6]]

# %%
plt.figure(figsize=(8, 8))
sns.distplot(wine_data['total sulfur dioxide'], color='g', bins=100, hist_kws={'alpha':0.5});
# Out:
# C:\Users\valou\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
wine_data.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %%
# .describe() displays summary statistics for wine dataframe
print(wine_data['total sulfur dioxide'].describe())
# wine_data.describe(include=['float'])
# Out:
# count    6497.000000
# mean      115.744574
# std        56.521855
# min         6.000000
# 25%        77.000000
# 50%       118.000000
# 75%       156.000000
# max       440.000000
# Name: total sulfur dioxide, dtype: float64

# %%
from collections import Counter
df_wine = wine_data[['type', 'density', 'pH', 'alcohol','quality']]

for col in df_wine.columns:
    print('Count is:',len(Counter(df_wine[col])))
    print(df_wine[col].value_counts(),end="\n")
# Out:
# Count is: 2
# white    4898
# red      1599
# Name: type, dtype: int64
# Count is: 998
# 0.99720    69
# 0.99760    69
# 0.99800    64
# 0.99200    64
# 0.99280    63
#            ..
# 0.99015     1
# 0.99065     1
# 0.99127     1
# 1.00047     1
# 1.00016     1
# Name: density, Length: 998, dtype: int64
# Count is: 117
# 3.16    200
# 3.14    193
# 3.22    185
# 3.20    176
# 3.19    170
#        ...
# 2.84      1
# 2.77      1
# 2.72      1
# 3.81      1
# 3.85      1
# Name: pH, Length: 108, dtype: int64
# Count is: 111
# 9.500000     367
# 9.400000     332
# 9.200000     271
# 10.000000    229
# 10.500000    227
#             ...
# 10.566667      1
# 9.233333       1
# 10.533333      1
# 13.566667      1
# 11.433333      1
# Name: alcohol, Length: 111, dtype: int64
# Count is: 7
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: quality, dtype: int64

# %%
wine_data.groupby(['density', 'pH']).mean()
# Out:
#               fixed acidity  volatile acidity  citric acid  residual sugar  \
# density pH
# 0.98711 3.10       5.800000             0.240         0.28             1.4
# 0.98713 3.33       4.900000             0.330         0.31             1.2
# 0.98722 3.30       4.700000             0.670         0.09             1.0
# 0.98740 3.26       5.000000             0.610         0.12             1.3
# 0.98742 3.31       5.350000             0.300         0.30             1.2
# ...                     ...               ...          ...             ...
# 1.00315 2.92      15.533333             0.645         0.49             4.2
# 1.00320 2.95      15.600000             0.685         0.76             3.7
# 1.00369 3.18      10.200000             0.540         0.37            15.4
# 1.01030 3.15       7.900000             0.330         0.28            31.6
# 1.03898 3.39       7.800000             0.965         0.60            65.8
#
# ...

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Inputing missing data with mean

# %%
#missing data
wine_data.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
# impute missing values via the column mean 

from sklearn.impute import SimpleImputer 

# Using DataFrame to drop string columns 'white and red'
wine_data.drop(wine_data.columns[[0, 0]], axis=1, inplace=True)

imr = SimpleImputer(missing_values = np.nan, strategy = 'mean')
imr = imr.fit(wine_data.values)
imputed_data = imr.transform(wine_data.values)
imputed_data
# Out:
# array([[ 7.   ,  0.27 ,  0.36 , ...,  0.45 ,  8.8  ,  6.   ],
#        [ 6.3  ,  0.3  ,  0.34 , ...,  0.49 ,  9.5  ,  6.   ],
#        [ 8.1  ,  0.28 ,  0.4  , ...,  0.44 , 10.1  ,  6.   ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  0.75 , 11.   ,  6.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  0.71 , 10.2  ,  5.   ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  0.66 , 11.   ,  6.   ]])

# %%
wine_data.fillna(wine_data.mean())
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# #### Dropping duplicated rows

# %%
print("Shape :\n", wine_data.shape)
# Out:
# Shape :
#  (6497, 12)

# %%
# Finding rows containing duplicate data 
duplicate_rows_df = wine_data[wine_data.duplicated()]
print("Number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# Number of duplicate rows:  (1170, 12)

# %%
wine_data.count()
# Out:
# fixed acidity           6487
# volatile acidity        6489
# citric acid             6494
# residual sugar          6495
# chlorides               6495
# free sulfur dioxide     6497
# total sulfur dioxide    6497
# density                 6497
# pH                      6488
# sulphates               6493
# alcohol                 6497
# quality                 6497
# dtype: int64

# %%
# Found 1170 duplicate data and drop them from df 
wine_data = wine_data.drop_duplicates()
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 6            6.2              0.32         0.16             7.0      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 6                 30.0                 136.0   0.9949  3.18       0.47
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
wine_data.count()
# Out:
# fixed acidity           5317
# volatile acidity        5319
# citric acid             5324
# residual sugar          5325
# chlorides               5325
# free sulfur dioxide     5327
# total sulfur dioxide    5327
# density                 5327
# pH                      5318
# sulphates               5323
# alcohol                 5327
# quality                 5327
# dtype: int64

# %%
duplicate_rows_df = wine_data[wine_data.duplicated()]
print("Number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# Number of duplicate rows:  (0, 12)

# %% [markdown]
# ### Data Visualization

# %%
# Visualising barplot between white and red wine 
print(df_wine['type'].value_counts())
plt.figure(figsize=(7,7))
sns.barplot(x = df_wine['type'].value_counts().index, 
            y = df_wine['type'].value_counts().values,palette = "YlOrRd")

plt.xlabel('type')
plt.ylabel('Frequency')
plt.title('type Bar Plot')
plt.show()
# Out:
# white    4898
# red      1599
# Name: type, dtype: int64

# %%
# plotting using lmplot 
sns.lmplot(x ='density', y ='pH', data = df_wine)
# Show the plot
plt.show()

# %%
# draw scatter plot
plt.scatter(x="density", y="pH", data=df_wine, c ="blue") 
# To show the plot
plt.show()

# %%
# Using pairplot to show relation between all df columns with pH column
for i in range(0, len(wine_data.columns), 5):
    sns.pairplot(data=wine_data,
                x_vars=wine_data.columns[i:i+5],
                y_vars=['pH'])
